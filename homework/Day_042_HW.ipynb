# %% [markdown]
# ## 作業
#
# 作業1：試著調整 Decision Tree 中的參數，並觀察是否會改變結果？
# 作業2：改用其他資料集 (diabetes, wine)，並與迴歸模型的結果進行比較

# %% [markdown]
# ## 撰寫方向
# - 以決策樹的深度(max_depth) 為例，探索樹的深度與模型預測力之間的關係

# %%
from sklearn.datasets import load_diabetes, load_wine
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %%
# 讀取 Boston 資料
diabetes = load_diabetes()

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.1, random_state=4)

# 設定深度集合
maxDepthList = list(range(1, 51))

mseList = list()
for oneDepth in maxDepthList:
    # 建立一個決策樹迴歸模型
    regr = DecisionTreeRegressor(max_depth = oneDepth)
    
    # 將訓練資料丟進去模型訓練
    regr.fit(x_train, y_train)
    
    # 將測試資料丟進模型得到預測結果
    y_pred = regr.predict(x_test)

    # 計算均方誤差(MSE)
    print("Max Depth: {}, Mean squared error: {}".format(oneDepth, round(mean_squared_error(y_test, y_pred), 2)) )
    
    # 將 MSE 結果儲存起來
    mseList.append(mean_squared_error(y_test, y_pred))
# Out:
# Max Depth: 1, Mean squared error: 4316.99
# Max Depth: 2, Mean squared error: 3124.94
# Max Depth: 3, Mean squared error: 3538.64
# Max Depth: 4, Mean squared error: 3950.28
# Max Depth: 5, Mean squared error: 3879.65
# Max Depth: 6, Mean squared error: 4686.05
# Max Depth: 7, Mean squared error: 5850.65
# Max Depth: 8, Mean squared error: 7229.9
# Max Depth: 9, Mean squared error: 7306.62
# Max Depth: 10, Mean squared error: 7350.86
# Max Depth: 11, Mean squared error: 7735.48
# Max Depth: 12, Mean squared error: 7894.08
# Max Depth: 13, Mean squared error: 7560.81
# Max Depth: 14, Mean squared error: 8209.93
# Max Depth: 15, Mean squared error: 7309.79
# Max Depth: 16, Mean squared error: 7179.49
# Max Depth: 17, Mean squared error: 7368.49
# Max Depth: 18, Mean squared error: 7879.53
# Max Depth: 19, Mean squared error: 7229.09
# Max Depth: 20, Mean squared error: 7592.07
# Max Depth: 21, Mean squared error: 7509.58
# Max Depth: 22, Mean squared error: 8693.73
# Max Depth: 23, Mean squared error: 7814.93
# Max Depth: 24, Mean squared error: 7639.16
# Max Depth: 25, Mean squared error: 7585.49
# Max Depth: 26, Mean squared error: 7676.0
# Max Depth: 27, Mean squared error: 7529.91
# Max Depth: 28, Mean squared error: 7636.04
# Max Depth: 29, Mean squared error: 7884.04
# Max Depth: 30, Mean squared error: 7696.67
# Max Depth: 31, Mean squared error: 7769.38
# Max Depth: 32, Mean squared error: 7621.22
# Max Depth: 33, Mean squared error: 8433.89
# Max Depth: 34, Mean squared error: 7513.04
# Max Depth: 35, Mean squared error: 7245.04
# Max Depth: 36, Mean squared error: 7416.82
# Max Depth: 37, Mean squared error: 7606.29
# Max Depth: 38, Mean squared error: 7237.44
# Max Depth: 39, Mean squared error: 7670.24
# Max Depth: 40, Mean squared error: 7522.84
# Max Depth: 41, Mean squared error: 7728.53
# Max Depth: 42, Mean squared error: 7213.18
# Max Depth: 43, Mean squared error: 7072.42
# Max Depth: 44, Mean squared error: 7745.93
# Max Depth: 45, Mean squared error: 7591.0
# Max Depth: 46, Mean squared error: 7746.91
# Max Depth: 47, Mean squared error: 7388.4
# Max Depth: 48, Mean squared error: 8032.58
# Max Depth: 49, Mean squared error: 7532.0
# Max Depth: 50, Mean squared error: 7776.87

# %%
# 繪製折線圖探索出樹的深度與 MSE 之間的關係
# 從結果可知，過多的深度反而讓 MSE 提升，產生過擬合的現象
import matplotlib.pyplot as plt
plt.plot(maxDepthList, mseList)
plt.xlabel("Max Depth")
plt.ylabel("Mean Squared Error")
plt.show()

# %%
# 讀取 wine 資料
wine = load_wine()

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.1, random_state=4)

# 設定深度集合
maxDepthList = list(range(1, 51))

accList = list()
for oneDepth in maxDepthList:
    # 建立一個決策樹分類模型
    regc = DecisionTreeClassifier(max_depth = oneDepth)
    
    # 將訓練資料丟進去模型訓練
    regc.fit(x_train, y_train)
    
    # 將測試資料丟進模型得到預測結果
    y_pred = regc.predict(x_test)

    # 計算準確度
    acc = accuracy_score(y_test, y_pred)
    print("Max Depth: {}, Accuracy: {}".format(oneDepth, round(acc, 2)) )

    # 將 MSE 結果儲存起來
    accList.append(acc)
# Out:
# Max Depth: 1, Accuracy: 0.67
# Max Depth: 2, Accuracy: 0.89
# Max Depth: 3, Accuracy: 0.94
# Max Depth: 4, Accuracy: 0.94
# Max Depth: 5, Accuracy: 1.0
# Max Depth: 6, Accuracy: 0.89
# Max Depth: 7, Accuracy: 0.94
# Max Depth: 8, Accuracy: 1.0
# Max Depth: 9, Accuracy: 0.94
# Max Depth: 10, Accuracy: 1.0
# Max Depth: 11, Accuracy: 1.0
# Max Depth: 12, Accuracy: 0.89
# Max Depth: 13, Accuracy: 1.0
# Max Depth: 14, Accuracy: 0.94
# Max Depth: 15, Accuracy: 0.89
# Max Depth: 16, Accuracy: 0.94
# Max Depth: 17, Accuracy: 0.94
# Max Depth: 18, Accuracy: 0.94
# Max Depth: 19, Accuracy: 1.0
# Max Depth: 20, Accuracy: 0.83
# Max Depth: 21, Accuracy: 1.0
# Max Depth: 22, Accuracy: 0.94
# Max Depth: 23, Accuracy: 1.0
# Max Depth: 24, Accuracy: 0.94
# Max Depth: 25, Accuracy: 0.89
# Max Depth: 26, Accuracy: 1.0
# Max Depth: 27, Accuracy: 0.89
# Max Depth: 28, Accuracy: 0.94
# Max Depth: 29, Accuracy: 1.0
# Max Depth: 30, Accuracy: 0.94
# Max Depth: 31, Accuracy: 1.0
# Max Depth: 32, Accuracy: 0.89
# Max Depth: 33, Accuracy: 0.89
# Max Depth: 34, Accuracy: 0.94
# Max Depth: 35, Accuracy: 0.94
# Max Depth: 36, Accuracy: 0.94
# Max Depth: 37, Accuracy: 1.0
# Max Depth: 38, Accuracy: 0.94
# Max Depth: 39, Accuracy: 0.89
# Max Depth: 40, Accuracy: 0.94
# Max Depth: 41, Accuracy: 0.89
# Max Depth: 42, Accuracy: 1.0
# Max Depth: 43, Accuracy: 0.94
# Max Depth: 44, Accuracy: 0.94
# Max Depth: 45, Accuracy: 1.0
# Max Depth: 46, Accuracy: 0.89
# Max Depth: 47, Accuracy: 1.0
# Max Depth: 48, Accuracy: 0.94
# Max Depth: 49, Accuracy: 1.0
# Max Depth: 50, Accuracy: 1.0

# %%
# 繪製折線圖探索出樹的深度與 Accuracy 之間的關係
# 從結果可知，當樹的深度達到第五層時，準確度就會趨於平穩的狀態，有時多預測對一筆，有時反而多錯一筆。
import matplotlib.pyplot as plt
plt.plot(maxDepthList, accList)
plt.xlabel("Max Depth")
plt.ylabel("Accuracy")
plt.show()
