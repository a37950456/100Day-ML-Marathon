# %% [markdown]
# ## 作業
#
# 作業1：試著調整 Random Forest 中的參數，並觀察是否會改變結果？
# 作業2：改用其他資料集 (diabetes, wine)，仔細探索一個參數對模型預測力的變化。

# %% [markdown]
# ## 撰寫方向
# - 本作業以 n_estimators 為例，探討不同數量決策樹下，隨機森林準確度差異

# %%
from sklearn.datasets import load_diabetes, load_wine
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %%
# 讀取 Diabete 資料
diabete = load_diabetes()

# 建立 n_estimators 集合
n_estimatorsList = list(range(100, 10000, 100))

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(diabete.data, diabete.target, test_size=0.1, random_state=4)

mseList = list()
for oneEstimators in n_estimatorsList:
    # 建立一個隨機森林迴歸模型
    regr = RandomForestRegressor(n_estimators = oneEstimators)
    
    # 將訓練資料丟進去模型訓練
    regr.fit(x_train, y_train)
    
    # 將測試資料丟進模型得到預測結果
    y_pred = regr.predict(x_test)

    # 用均方誤差(Mean squared error) 評估模型成效
    print("n_estimators: {}, Mean squared error: {}".format(oneEstimators, round(mean_squared_error(y_test, y_pred), 2)))

    # 將 MSE 結果儲存起來
    mseList.append(mean_squared_error(y_test, y_pred))
# Out:
# n_estimators: 100, Mean squared error: 3489.88
# n_estimators: 200, Mean squared error: 3202.71
# n_estimators: 300, Mean squared error: 3209.41
# n_estimators: 400, Mean squared error: 3255.78
# n_estimators: 500, Mean squared error: 3337.59
# n_estimators: 600, Mean squared error: 3271.38
# n_estimators: 700, Mean squared error: 3301.81
# n_estimators: 800, Mean squared error: 3285.56
# n_estimators: 900, Mean squared error: 3361.52
# n_estimators: 1000, Mean squared error: 3328.5
# n_estimators: 1100, Mean squared error: 3252.41
# n_estimators: 1200, Mean squared error: 3334.96
# n_estimators: 1300, Mean squared error: 3300.93
# n_estimators: 1400, Mean squared error: 3271.08
# n_estimators: 1500, Mean squared error: 3271.68
# n_estimators: 1600, Mean squared error: 3271.52
# n_estimators: 1700, Mean squared error: 3322.29
# n_estimators: 1800, Mean squared error: 3283.78
# n_estimators: 1900, Mean squared error: 3317.46
# n_estimators: 2000, Mean squared error: 3282.42
# n_estimators: 2100, Mean squared error: 3303.75
# n_estimators: 2200, Mean squared error: 3327.74
# n_estimators: 2300, Mean squared error: 3258.3
# n_estimators: 2400, Mean squared error: 3336.29
# n_estimators: 2500, Mean squared error: 3278.27
# n_estimators: 2600, Mean squared error: 3283.62
# n_estimators: 2700, Mean squared error: 3286.67
# n_estimators: 2800, Mean squared error: 3291.82
# n_estimators: 2900, Mean squared error: 3280.41
# n_estimators: 3000, Mean squared error: 3276.45
# n_estimators: 3100, Mean squared error: 3331.76
# n_estimators: 3200, Mean squared error: 3286.07
# n_estimators: 3300, Mean squared error: 3302.29
# n_estimators: 3400, Mean squared error: 3253.05
# n_estimators: 3500, Mean squared error: 3283.0
# n_estimators: 3600, Mean squared error: 3277.3
# n_estimators: 3700, Mean squared error: 3330.21
# n_estimators: 3800, Mean squared error: 3286.3
# n_estimators: 3900, Mean squared error: 3297.03
# n_estimators: 4000, Mean squared error: 3330.76
# n_estimators: 4100, Mean squared error: 3284.63
# n_estimators: 4200, Mean squared error: 3273.18
# n_estimators: 4300, Mean squared error: 3300.96
# n_estimators: 4400, Mean squared error: 3283.31
# n_estimators: 4500, Mean squared error: 3292.13
# n_estimators: 4600, Mean squared error: 3297.62
# n_estimators: 4700, Mean squared error: 3297.24
# n_estimators: 4800, Mean squared error: 3290.41
# n_estimators: 4900, Mean squared error: 3305.92
# n_estimators: 5000, Mean squared error: 3285.1
# n_estimators: 5100, Mean squared error: 3321.45
# n_estimators: 5200, Mean squared error: 3279.7
# n_estimators: 5300, Mean squared error: 3317.58
# n_estimators: 5400, Mean squared error: 3291.5
# n_estimators: 5500, Mean squared error: 3283.07
# n_estimators: 5600, Mean squared error: 3317.26
# n_estimators: 5700, Mean squared error: 3278.68
# n_estimators: 5800, Mean squared error: 3277.99
# n_estimators: 5900, Mean squared error: 3266.02
# n_estimators: 6000, Mean squared error: 3274.87
# n_estimators: 6100, Mean squared error: 3291.28
# n_estimators: 6200, Mean squared error: 3289.71
# n_estimators: 6300, Mean squared error: 3273.88
# n_estimators: 6400, Mean squared error: 3266.62
# n_estimators: 6500, Mean squared error: 3305.78
# n_estimators: 6600, Mean squared error: 3277.22
# n_estimators: 6700, Mean squared error: 3290.49
# n_estimators: 6800, Mean squared error: 3306.47
# n_estimators: 6900, Mean squared error: 3313.02
# n_estimators: 7000, Mean squared error: 3279.53
# n_estimators: 7100, Mean squared error: 3271.26
# n_estimators: 7200, Mean squared error: 3293.91
# n_estimators: 7300, Mean squared error: 3303.12
# n_estimators: 7400, Mean squared error: 3307.12
# n_estimators: 7500, Mean squared error: 3287.08
# n_estimators: 7600, Mean squared error: 3303.64
# n_estimators: 7700, Mean squared error: 3299.52
# n_estimators: 7800, Mean squared error: 3304.21
# n_estimators: 7900, Mean squared error: 3289.32
# n_estimators: 8000, Mean squared error: 3265.06
# n_estimators: 8100, Mean squared error: 3331.83
# n_estimators: 8200, Mean squared error: 3290.94
# n_estimators: 8300, Mean squared error: 3278.04
# n_estimators: 8400, Mean squared error: 3267.15
# n_estimators: 8500, Mean squared error: 3285.74
# n_estimators: 8600, Mean squared error: 3284.17
# n_estimators: 8700, Mean squared error: 3308.16
# n_estimators: 8800, Mean squared error: 3292.74
# n_estimators: 8900, Mean squared error: 3277.72
# n_estimators: 9000, Mean squared error: 3276.96
# n_estimators: 9100, Mean squared error: 3276.37
# n_estimators: 9200, Mean squared error: 3286.06
# n_estimators: 9300, Mean squared error: 3294.11
# n_estimators: 9400, Mean squared error: 3286.37
# n_estimators: 9500, Mean squared error: 3271.46
# n_estimators: 9600, Mean squared error: 3273.58
# n_estimators: 9700, Mean squared error: 3288.66
# n_estimators: 9800, Mean squared error: 3296.6
# n_estimators: 9900, Mean squared error: 3294.98

# %%
# 繪製 n_estimators 與 MSE 之間的關係
# 從結果中可知，n_estimators 與 MSE 並沒有什麼關係，當 n_estimators 越多時並不會讓 MSE 有效下降。
import matplotlib.pyplot as plt
plt.plot(n_estimatorsList, mseList)
plt.ylabel("Mean Squared Error")
plt.xlabel("n_estimators")
plt.show()

# %%
# 讀取 wine 資料
wine = load_wine()

# 建立 n_estimators 集合
n_estimatorsList = list(range(100, 10000, 100))

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.1, random_state=4)

accList = list()
for oneEstimators in n_estimatorsList:

    # 建立一個隨機森林分類模型
    regc = RandomForestClassifier()
    
    # 將訓練資料丟進去模型訓練
    regc.fit(x_train, y_train)
    
    # 將測試資料丟進模型得到預測結果
    y_pred = regc.predict(x_test)

    # 用準確度(Accuracy)評估模型成效
    acc = accuracy_score(y_test, y_pred)
    print("n_estimators: {}, Accuracy: {}".format(oneEstimators, round(acc, 2)))

    # 將 Accuracy 結果儲存起來
    accList.append(acc)
# Out:
# n_estimators: 100, Accuracy: 1.0
# n_estimators: 200, Accuracy: 1.0
# n_estimators: 300, Accuracy: 1.0
# n_estimators: 400, Accuracy: 1.0
# n_estimators: 500, Accuracy: 1.0
# n_estimators: 600, Accuracy: 1.0
# n_estimators: 700, Accuracy: 1.0
# n_estimators: 800, Accuracy: 1.0
# n_estimators: 900, Accuracy: 1.0
# n_estimators: 1000, Accuracy: 1.0
# n_estimators: 1100, Accuracy: 1.0
# n_estimators: 1200, Accuracy: 1.0
# n_estimators: 1300, Accuracy: 1.0
# n_estimators: 1400, Accuracy: 1.0
# n_estimators: 1500, Accuracy: 1.0
# n_estimators: 1600, Accuracy: 1.0
# n_estimators: 1700, Accuracy: 1.0
# n_estimators: 1800, Accuracy: 1.0
# n_estimators: 1900, Accuracy: 1.0
# n_estimators: 2000, Accuracy: 1.0
# n_estimators: 2100, Accuracy: 1.0
# n_estimators: 2200, Accuracy: 1.0
# n_estimators: 2300, Accuracy: 1.0
# n_estimators: 2400, Accuracy: 1.0
# n_estimators: 2500, Accuracy: 1.0
# n_estimators: 2600, Accuracy: 1.0
# n_estimators: 2700, Accuracy: 1.0
# n_estimators: 2800, Accuracy: 1.0
# n_estimators: 2900, Accuracy: 1.0
# n_estimators: 3000, Accuracy: 1.0
# n_estimators: 3100, Accuracy: 1.0
# n_estimators: 3200, Accuracy: 1.0
# n_estimators: 3300, Accuracy: 1.0
# n_estimators: 3400, Accuracy: 1.0
# n_estimators: 3500, Accuracy: 1.0
# n_estimators: 3600, Accuracy: 1.0
# n_estimators: 3700, Accuracy: 1.0
# n_estimators: 3800, Accuracy: 1.0
# n_estimators: 3900, Accuracy: 1.0
# n_estimators: 4000, Accuracy: 1.0
# n_estimators: 4100, Accuracy: 1.0
# n_estimators: 4200, Accuracy: 1.0
# n_estimators: 4300, Accuracy: 1.0
# n_estimators: 4400, Accuracy: 1.0
# n_estimators: 4500, Accuracy: 1.0
# n_estimators: 4600, Accuracy: 1.0
# n_estimators: 4700, Accuracy: 1.0
# n_estimators: 4800, Accuracy: 1.0
# n_estimators: 4900, Accuracy: 1.0
# n_estimators: 5000, Accuracy: 1.0
# n_estimators: 5100, Accuracy: 1.0
# n_estimators: 5200, Accuracy: 1.0
# n_estimators: 5300, Accuracy: 1.0
# n_estimators: 5400, Accuracy: 1.0
# n_estimators: 5500, Accuracy: 1.0
# n_estimators: 5600, Accuracy: 1.0
# n_estimators: 5700, Accuracy: 1.0
# n_estimators: 5800, Accuracy: 1.0
# n_estimators: 5900, Accuracy: 1.0
# n_estimators: 6000, Accuracy: 1.0
# n_estimators: 6100, Accuracy: 1.0
# n_estimators: 6200, Accuracy: 1.0
# n_estimators: 6300, Accuracy: 1.0
# n_estimators: 6400, Accuracy: 1.0
# n_estimators: 6500, Accuracy: 1.0
# n_estimators: 6600, Accuracy: 1.0
# n_estimators: 6700, Accuracy: 1.0
# n_estimators: 6800, Accuracy: 1.0
# n_estimators: 6900, Accuracy: 1.0
# n_estimators: 7000, Accuracy: 1.0
# n_estimators: 7100, Accuracy: 1.0
# n_estimators: 7200, Accuracy: 1.0
# n_estimators: 7300, Accuracy: 1.0
# n_estimators: 7400, Accuracy: 1.0
# n_estimators: 7500, Accuracy: 1.0
# n_estimators: 7600, Accuracy: 1.0
# n_estimators: 7700, Accuracy: 1.0
# n_estimators: 7800, Accuracy: 1.0
# n_estimators: 7900, Accuracy: 1.0
# n_estimators: 8000, Accuracy: 1.0
# n_estimators: 8100, Accuracy: 1.0
# n_estimators: 8200, Accuracy: 1.0
# n_estimators: 8300, Accuracy: 1.0
# n_estimators: 8400, Accuracy: 1.0
# n_estimators: 8500, Accuracy: 1.0
# n_estimators: 8600, Accuracy: 1.0
# n_estimators: 8700, Accuracy: 1.0
# n_estimators: 8800, Accuracy: 1.0
# n_estimators: 8900, Accuracy: 1.0
# n_estimators: 9000, Accuracy: 1.0
# n_estimators: 9100, Accuracy: 1.0
# n_estimators: 9200, Accuracy: 1.0
# n_estimators: 9300, Accuracy: 1.0
# n_estimators: 9400, Accuracy: 1.0
# n_estimators: 9500, Accuracy: 1.0
# n_estimators: 9600, Accuracy: 1.0
# n_estimators: 9700, Accuracy: 1.0
# n_estimators: 9800, Accuracy: 1.0
# n_estimators: 9900, Accuracy: 1.0

# %%
# 繪製 n_estimators 與 MSE 之間的關係
# 從結果中可知，因 Random Forest 模型對 Wine Datasets 來說蠻強大的，不論 n_estimators 設定為多少，Accuracy 都可以是 1.0
import matplotlib.pyplot as plt
plt.plot(n_estimatorsList, accList)
plt.ylabel("Accuracy")
plt.xlabel("n_estimators")
plt.show()
